# %% [markdown]
# # Computer Vision
# ## ResNet50 Model Image Classification
# ## Victoria Hall
# ## 7.17.22
#
#
# 1. The purpose of this project was to perform image classification with the ResNet50 on a select group of images.

# %%
#importing packages
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

# %%
#printing image
from matplotlib import image as mpimg
plt.title("Ball")
image = mpimg.imread("images/ball.jpeg")
plt.imshow(image)
plt.show()

#prepping image
from tensorflow.keras.preprocessing import image
model = ResNet50(weights='imagenet')
img_path = 'images/ball.jpeg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n04254680', 'soccer_ball', 0.9994784), ('n04540053', 'volleyball', 0.0003487557), ('n03530642', 'honeycomb', 8.568058e-05)]

# %%
from matplotlib import image as mpimg
plt.title("Car")
image = mpimg.imread("images/car.jpeg")
plt.imshow(image)
plt.show()

from tensorflow.keras.preprocessing import image
model = ResNet50(weights='imagenet')
img_path = 'images/car.jpeg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n04285008', 'sports_car', 0.48022068), ('n03930630', 'pickup', 0.26488152), ('n04037443', 'racer', 0.16880336)]

# %%
from matplotlib import image as mpimg
plt.title("Flower")
image = mpimg.imread("images/flower.jpeg")
plt.imshow(image)
plt.show()

from tensorflow.keras.preprocessing import image
model = ResNet50(weights='imagenet')
img_path = 'images/flower.jpeg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n12620546', 'hip', 0.44564402), ('n03991062', 'pot', 0.09278232), ('n03000134', 'chainlink_fence', 0.08015899)]

# %%
from matplotlib import image as mpimg
plt.title("Lion")
image = mpimg.imread("images/lion.jpeg")
plt.imshow(image)
plt.show()

from tensorflow.keras.preprocessing import image
model = ResNet50(weights='imagenet')
img_path = 'images/lion.jpeg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02129165', 'lion', 0.99115366), ('n02480495', 'orangutan', 0.0010882786), ('n02483362', 'gibbon', 0.00083908153)]

# %%
from matplotlib import image as mpimg
plt.title("Star")
image = mpimg.imread("images/star.jpeg")
plt.imshow(image)
plt.show()

from tensorflow.keras.preprocessing import image
model = ResNet50(weights='imagenet')
img_path = 'images/star.jpeg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n04548280', 'wall_clock', 0.2569128), ('n04192698', 'shield', 0.24968614), ('n03291819', 'envelope', 0.07286203)]
