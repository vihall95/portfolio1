# %% [markdown]
# # Histograms, BoxPlots, and Bullet Charts
#
# ## Victoria Hall
#
# ## 5.30.2022

# %%
#Loading initial packages for reading in data
import pandas as pd
import numpy as np

# %%
#importing crime datasaet as dataframe
crime_df = pd.read_csv("crimeratesbystate-formatted.csv")
crime_df.head(10)
# Out:
#                   state  murder  forcible_rape  robbery  aggravated_assault  \
# 0        United States      5.6           31.7    140.7               291.1
# 1              Alabama      8.2           34.3    141.4               247.8
# 2               Alaska      4.8           81.1     80.9               465.1
# 3              Arizona      7.5           33.8    144.4               327.4
# 4              Arkansas     6.7           42.9     91.1               386.8
# 5           California      6.9           26.0    176.1               317.3
# 6             Colorado      3.7           43.4     84.6               264.7
# 7          Connecticut      2.9           20.0    113.0               138.6
# 8             Delaware      4.4           44.7    154.8               428.2
# 9  District of Columbia    35.4           30.2    672.1               721.3
#
#    burglary  larceny_theft  motor_vehicle_theft
# 0     726.7         2286.3                416.7
# ...

# %%
#importing education dataset as dataframe
education_df = pd.read_csv("education.csv")
education_df.head(10)
# Out:
#                   state  reading  math  writing  percent_graduates_sat  \
# 0         United States      501   515      493                     46
# 1               Alabama      557   552      549                      7
# 2                Alaska      520   516      492                     46
# 3               Arizona      516   521      497                     26
# 4              Arkansas      572   572      556                      5
# 5            California      500   513      498                     49
# 6              Colorado      568   575      555                     20
# 7           Connecticut      509   513      512                     83
# 8              Delaware      495   498      484                     71
# 9  District of Columbia      466   451      461                     79
#
#    pupil_staff_ratio  dropout_rate
# 0                7.9           4.4
# 1                6.7           2.3
# 2                7.9           7.3
# 3               10.4           7.6
# ...

# %%
#importing plotting packages
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Histogram

# %%
#checking for missing values
crime_df.isnull().sum()
# Out:
# state                  0
# murder                 0
# forcible_rape          0
# robbery                0
# aggravated_assault     0
# burglary               0
# larceny_theft          0
# motor_vehicle_theft    0
# dtype: int64

# %%
print("Max:",crime_df.murder.max())
print("Min:",crime_df.murder.min())
print("Count:",crime_df.murder.count())
print("Mean:", crime_df.murder.mean())
print("Median:", crime_df.murder.median())
print("Mode:", crime_df.murder.mode())
# Out:
# Max: 35.4
# Min: 1.1
# Count: 52
# Mean: 5.321153846153846
# Median: 4.8
# Mode: 0    6.1
# Name: murder, dtype: float64

# %%
#Creating initial plot to see basic details
sns.histplot(data = crime_df,x='murder')
plt.show()

# %%
g = sns.histplot(data = crime_df, x='murder',color='navy',alpha=1) #Creating initital Plot
sns.set_style("white") #white background without gridlines
sns.despine() #removing plot outlines
plt.suptitle("U.S. Murder Rate Disbution",x=.344,y=1.05,fontsize=15,fontweight='bold') #title position
plt.title("Washington DC's murder rate is 5 times\nhigher than the state average of 5.3",loc='left',fontsize=12) #adding note
g.set(xlabel="Murder Rate",ylabel="# of States")
g.annotate("Washington DC",xy=(34.2,1),xytext=(29,8),arrowprops = dict(facecolor='red',shrink=0.05)) #showing DC datapoint
plt.show()

# %% [markdown]
# ### Box Plot

# %%
scores = education_df[['reading','math','writing']] #new df with just SAT scores
scores.drop([0,0],inplace=True) #dropping first row which is the US average
# Out:
# C:\Users\hallt\AppData\Local\Temp\ipykernel_3480\1895117919.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores.drop([0,0],inplace=True) #dropping first row which is the US average

# %%
scores.head(10)
# Out:
#     reading  math  writing
# 1       557   552      549
# 2       520   516      492
# 3       516   521      497
# 4       572   572      556
# 5       500   513      498
# 6       568   575      555
# 7       509   513      512
# 8       495   498      484
# 9       466   451      461
# 10      497   498      480

# %%
print('Reading:\n',education_df['reading'].describe())
print('Math:\n',education_df['math'].describe())
print('Writing:\n',education_df['writing'].describe())
# Out:
# Reading:
#  count     52.000000
# mean     533.807692
# std       40.617797
# min      466.000000
# 25%      497.750000
# 50%      523.000000
# 75%      571.250000
# max      610.000000
# Name: reading, dtype: float64
# Math:
#  count     52.000000
# mean     538.365385
# std       40.963412
# min      451.000000
# 25%      505.750000
# 50%      525.500000
# 75%      571.250000
# max      615.000000
# Name: math, dtype: float64
# Writing:
#  count     52.000000
# mean     520.826923
# std       39.246192
# min      455.000000
# 25%      490.000000
# 50%      510.000000
# 75%      557.500000
# max      588.000000
# Name: writing, dtype: float64

# %%
#finding index of rows with max and min values
print(scores.idxmax())
print(scores.idxmin())
# Out:
# reading    16
# math       16
# writing    16
# dtype: int64
# reading     9
# math        9
# writing    20
# dtype: int64

# %%
education_df.loc[[16]]
# Out:
#    state  reading  math  writing  percent_graduates_sat  pupil_staff_ratio  \
# 16  Iowa      610   615      588                      3                6.8
#
#     dropout_rate
# 16           2.3

# %%
education_df.loc[[20]]
# Out:
#     state  reading  math  writing  percent_graduates_sat  pupil_staff_ratio  \
# 20  Maine      468   467      455                     90                4.9
#
#     dropout_rate
# 20           5.3

# %%
education_df.loc[[9]]
# Out:
#                   state  reading  math  writing  percent_graduates_sat  \
# 9  District of Columbia      466   451      461                     79
#
#    pupil_staff_ratio  dropout_rate
# 9                6.3           7.1

# %%
#Creating initial plot to see basic details
sns.boxplot(data=scores,orient="h")
# Out:
# <AxesSubplot:>

# %%
scores.rename(columns={'reading':"Reading","math": "Math","writing":"Writing"},inplace=True)
# Out:
# C:\Users\hallt\AppData\Local\Temp\ipykernel_3480\544238397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores.rename(columns={'reading':"Reading","math": "Math","writing":"Writing"},inplace=True)

# %%
z = sns.boxplot(data=scores,orient="h",palette='pastel' ) #Creating initital Plot
sns.set_style("white") #white background without gridlines
sns.despine() #removing plot outlines
plt.yticks(fontsize= 14,fontweight="bold")
plt.xticks(fontsize= 12)
plt.suptitle("U.S. SAT Scores",x=.28,y=1.03,fontsize=18,fontweight='bold') #title position
plt.title("Iowa has highest scores of all 3 subjects.\nDC and Maine have the lowest scores.",loc='left',fontsize=12) #adding note
z.set_xlabel("",fontsize=14,fontweight="bold")
plt.show()

# %% [markdown]
# ### Bullet Chart

# %%
columnnames = education_df.columns
print(columnnames)
# Out:
# Index(['state', 'reading', 'math', 'writing', 'percent_graduates_sat',
#        'pupil_staff_ratio', 'dropout_rate'],
#       dtype='object')

# %%
#Creating new dataframe of states in the deep south plus the US
deep_south = pd.DataFrame(columns=columnnames)
states = ['United States','Louisiana', 'Mississippi', 'Alabama', 'Georgia', 'South Carolina']

for state in states:
    new_row = education_df.loc[education_df['state'] == state]
    deep_south = deep_south.append(new_row, ignore_index=True)
   
deep_south.head(10)
# Out:
# C:\Users\hallt\AppData\Local\Temp\ipykernel_3480\1800341546.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   deep_south = deep_south.append(new_row, ignore_index=True)
#             state reading math writing percent_graduates_sat  \
# 0   United States     501  515     493                    46
# 1       Louisiana     563  558     555                     7
# 2     Mississippi     567  554     559                     4
# 3         Alabama     557  552     549                     7
# 4         Georgia     490  491     479                    71
# 5  South Carolina     486  496     470                    67
#
#   pupil_staff_ratio dropout_rate
# 0               7.9          4.4
# 1               6.8          7.4
# 2               6.9          4.3
# 3               6.7          2.3
# 4               7.0          4.6
# 5              10.8          3.9

# %%
education_df['percent_graduates_sat'].idxmax()
# Out:
# 20

# %%
education_df.loc[[20]]
# Out:
#     state  reading  math  writing  percent_graduates_sat  pupil_staff_ratio  \
# 20  Maine      468   467      455                     90                4.9
#
#     dropout_rate
# 20           5.3

# %%
deep_south.drop(columns=['pupil_staff_ratio','dropout_rate','math','reading','writing'],inplace=True)

# %%
#looking at quantiles to create limits 
np.quantile(education_df['percent_graduates_sat'],[0,0.25,0.5,0.75,1])
# Out:
# array([ 3.  ,  6.75, 34.  , 66.25, 90.  ])

# %%
deep_south.head(10)
# Out:
#             state percent_graduates_sat
# 0   United States                    46
# 1       Louisiana                     7
# 2     Mississippi                     4
# 3         Alabama                     7
# 4         Georgia                    71
# 5  South Carolina                    67

# %%
#Iowa has the highest scores so using those as a target
deep_south['goal'] = [90,90,90,90,90,90]

# %%
deep_south.head(10)
# Out:
#             state percent_graduates_sat  goal
# 0   United States                    46    90
# 1       Louisiana                     7    90
# 2     Mississippi                     4    90
# 3         Alabama                     7    90
# 4         Georgia                    71    90
# 5  South Carolina                    67    90

# %%
#Creating a list of tuples to put into function
tdeep_south = deep_south.to_records(index=False)
tdeep_south = list(tdeep_south)

# %%
def bulletgraph(data=None, limits=None, labels=None, axis_label=None, title=None,
                size=(5, 3), palette=None, formatter=None, target_color="gray",
                bar_color="black", label_color="gray"):
    """ Build out a bullet graph image
        Args:
            data = List of labels, measures and targets
            limits = list of range valules
            labels = list of descriptions of the limit ranges
            axis_label = string describing x axis
            title = string title of plot
            size = tuple for plot size
            palette = a seaborn palette
            formatter = matplotlib formatter object for x axis
            target_color = color string for the target line
            bar_color = color string for the small bar
            label_color = color string for the limit label text
        Returns:
            a matplotlib figure
    """
    # Determine the max value for adjusting the bar height
    # Dividing by 10 seems to work pretty well
    h = limits[-1] / 10

    # Use the green palette as a sensible default
    if palette is None:
        palette = sns.light_palette("green", len(limits), reverse=False)

    # Must be able to handle one or many data sets via multiple subplots
    if len(data) == 1:
        fig, ax = plt.subplots(figsize=size, sharex=True)
    else:
        fig, axarr = plt.subplots(len(data), figsize=size, sharex=True)

    # Add each bullet graph bar to a subplot
    for idx, item in enumerate(data):

        # Get the axis from the array of axes returned when the plot is created
        if len(data) > 1:
            ax = axarr[idx]

        # Formatting to get rid of extra marking clutter
        ax.set_aspect('equal')
        ax.set_yticklabels([item[0]])
        ax.set_yticks([1])
        ax.spines['bottom'].set_visible(False)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['left'].set_visible(False)

        prev_limit = 0
        for idx2, lim in enumerate(limits):
            # Draw the bar
            ax.barh([1], lim - prev_limit, left=prev_limit, height=h,
                    color=palette[idx2])
            prev_limit = lim
        rects = ax.patches
        # The last item in the list is the value we're measuring
        # Draw the value we're measuring
        ax.barh([1], item[1], height=(h / 3), color=bar_color)

        # Need the ymin and max in order to make sure the target marker
        # fits
        ymin, ymax = ax.get_ylim()
        ax.vlines(
            item[2], ymin * .9, ymax * .9, linewidth=1.5, color=target_color)

    # Now make some labels
    if labels is not None:
        for rect, label in zip(rects, labels):
            height = rect.get_height()
            ax.text(
                rect.get_x() + rect.get_width() / 2,
                -height * .4,
                label,
                ha='center',
                va='bottom',
                color=label_color)
    if formatter:
        ax.xaxis.set_major_formatter(formatter)
    if axis_label:
        ax.set_xlabel(axis_label)
    if title:
        fig.suptitle(title, fontsize=14)
    fig.subplots_adjust(hspace=0)

# %%
bulletplot = bulletgraph(tdeep_south, limits=[6.75,66.25,90.0],
            labels=["Below", "Average","Above" ],size=(7,7),
            axis_label="Performance Measure", label_color="black",palette=None,
            bar_color="#252525", target_color='#f7f7f7',
            title="Deep South Dropout Rates")
# Out:
# C:\Users\hallt\AppData\Local\Temp\ipykernel_3480\340279462.py:43: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([item[0]])

# %% [markdown]
# ### Line Plot

# %%
education_df.head(10)
# Out:
#                   state  reading  math  writing  percent_graduates_sat  \
# 0         United States      501   515      493                     46
# 1               Alabama      557   552      549                      7
# 2                Alaska      520   516      492                     46
# 3               Arizona      516   521      497                     26
# 4              Arkansas      572   572      556                      5
# 5            California      500   513      498                     49
# 6              Colorado      568   575      555                     20
# 7           Connecticut      509   513      512                     83
# 8              Delaware      495   498      484                     71
# 9  District of Columbia      466   451      461                     79
#
#    pupil_staff_ratio  dropout_rate
# 0                7.9           4.4
# 1                6.7           2.3
# 2                7.9           7.3
# 3               10.4           7.6
# ...

# %%
#Creating a total SAT score column
education_df['total_score'] = education_df.reading + education_df.math + education_df.writing
education_df.head(10)
# Out:
#                   state  reading  math  writing  percent_graduates_sat  \
# 0         United States      501   515      493                     46
# 1               Alabama      557   552      549                      7
# 2                Alaska      520   516      492                     46
# 3               Arizona      516   521      497                     26
# 4              Arkansas      572   572      556                      5
# 5            California      500   513      498                     49
# 6              Colorado      568   575      555                     20
# 7           Connecticut      509   513      512                     83
# 8              Delaware      495   498      484                     71
# 9  District of Columbia      466   451      461                     79
#
#    pupil_staff_ratio  dropout_rate  total_score
# 0                7.9           4.4         1509
# 1                6.7           2.3         1658
# ...

# %%
#Dropping US from plot since it is an average of all the states
ed_df = education_df.drop(labels=0,axis=0)
ed_df.head(10)
# Out:
#                    state  reading  math  writing  percent_graduates_sat  \
# 1                Alabama      557   552      549                      7
# 2                 Alaska      520   516      492                     46
# 3                Arizona      516   521      497                     26
# 4               Arkansas      572   572      556                      5
# 5             California      500   513      498                     49
# 6               Colorado      568   575      555                     20
# 7            Connecticut      509   513      512                     83
# 8               Delaware      495   498      484                     71
# 9   District of Columbia      466   451      461                     79
# 10               Florida      497   498      480                     59
#
#     pupil_staff_ratio  dropout_rate  total_score
# 1                 6.7           2.3         1658
# 2                 7.9           7.3         1528
# ...

# %%
ed_df.shape
# Out:
# (51, 8)

# %%
#Creating  line plot
z = sns.relplot(x='percent_graduates_sat',y='total_score',kind='line',data=ed_df)
sns.set_style("white") #white background without gridlines
sns.despine() #removing plot outlines
plt.yticks(fontsize= 10)
plt.xticks(fontsize= 10)
plt.suptitle("SAT Scores v. Percent of Students that took the exam",fontsize=14,y=1.12,x=.65,fontweight='bold') #title position
plt.title("Scores tend to decrease as more students\ntake the exam. Perhaps only chigh acheiving\nstudents are taking the test in these states.",fontsize=12,loc='left') #adding note
plt.xlabel('Percent of Students',fontsize=12,fontweight="bold")
plt.ylabel('SAT Score',fontsize=12,fontweight="bold")
plt.show()
